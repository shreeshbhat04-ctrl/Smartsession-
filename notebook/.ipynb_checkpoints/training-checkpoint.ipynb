# %%
import os
import cv2
import math
import numpy as np
import pandas as pd
import mediapipe as mp

from mediapipe.tasks import python
from mediapipe.tasks.python import vision

# %%
base_options = python.BaseOptions(
    model_asset_path="face_landmarker.task"
)
options = vision.FaceLandmarkerOptions(
    base_options=base_options,
    num_faces=1,
     running_mode=vision.RunningMode.IMAGE, 
    output_face_blendshapes=False,
)
detector = vision.FaceLandmarker.create_from_options(options)
def euclid(p1, p2):
    return math.hypot(p1.x - p2.x, p1.y - p2.y)

#same until here

# %%
#so for implementing confusion i want to track eyebrow movement
def browratio(lm):
    brow_l = lm[107]
    brow_r = lm[336]
    face_l = lm[234]
    face_r = lm[454]
    facewidth = euclid(face_l, face_r)
    if facewidth == 0:
        return None
    return euclid(brow_l, brow_r) / facewidth

# %%
#mouth movement
def mouthfeatures(lm):
    left = lm[61]
    right = lm[291]
    top = lm[13]
    bottom = lm[14]
    nose = lm[1]
    face_l = lm[234]
    face_r = lm[454]
    facewidth = euclid(face_l, face_r)
    if facewidth == 0:
        return None, None, None
    mouthwidth = euclid(left, right) / facewidth
    mouthopen = euclid(top, bottom) / facewidth
    smileup = (nose.y - (left.y + right.y) / 2) / facewidth
    return mouthwidth, mouthopen, smileup

# %%
# head roll same logic
def headroll(lm):
    L = lm[234]
    R = lm[454]
    return math.degrees(math.atan2(R.y - L.y, R.x - L.x))

# %%
#gaze ratio aka left/rigth
def gazeratios(lm):
    iris = lm[474]
    inner = lm[263]
    outer = lm[362]
    eyewidth = euclid(inner, outer)
    if eyewidth == 0:
        return None, None
    gazex = euclid(iris, inner) / eyewidth
    # Vertical gaze
    candidates = [p.y for p in lm if abs(p.x - iris.x) < 0.02]
    if not candidates:
        return gazex, 0.5
    top = min(candidates)
    bottom = max(candidates)
    gazey = (iris.y - top) / max(bottom - top, 1e-6)
    return gazex, gazey

# %%
img_path = r"C:\Users\shree\intern\1\Smartsession-\notebook\dataset\confused\S057_003_00000013.png"

def extract_features(img_path):
    img = cv2.imread(img_path)
    if img is None:
        return None

    rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    mp_img = mp.Image(image_format=mp.ImageFormat.SRGB, data=rgb)

    result = detector.detect(mp_img)
    if not result.face_landmarks:
        return None

    lm = result.face_landmarks[0]

    brow = browratio(lm)
    mouth_w, mouth_open, smile_up = mouthfeatures(lm)
    roll = headroll(lm)
    gaze_x, gaze_y = gazeratios(lm)

    if len(lm) < 475:
        print("Insufficient landmarks:", len(lm))
        return None

    if None in (brow, mouth_w, mouth_open, smile_up, gaze_x, gaze_y):
        return None

    return [
        brow,
        smile_up,
        mouth_open,
        mouth_w,
        roll,
        gaze_x,
        gaze_y
    ]

# %%
feats = extract_features(img_path)
print(feats)
# Out:
# [0.19400454764271008, -0.15636782045533784, 0.012878125263748338, 0.34464763129793086, -3.7929761703189557, 0.1796557034941739, 0.24112019832695303]

# %%
DATASET_DIR = "dataset"
rows = []

for label in os.listdir(DATASET_DIR):
    folder = os.path.join(DATASET_DIR, label)
    if not os.path.isdir(folder):
        continue

    for fname in os.listdir(folder):
        if not fname.lower().endswith((".jpg", ".png", ".jpeg")):
            continue

        path = os.path.join(folder, fname)
        feats = extract_features(path)

        if feats is None:
            continue

        rows.append(feats + [label])

# %%
columns = [
    "brow_ratio",
    "smile_up",
    "mouth_open",
    "mouth_width",
    "head_roll",
    "gaze_x",
    "gaze_y",
    "label"
]

df = pd.DataFrame(rows, columns=columns)
print(df.shape)
df.head()
# Out:
# (346, 8)
#    brow_ratio  smile_up  mouth_open  mouth_width  head_roll    gaze_x  \
# 0    0.199959 -0.391801    0.001080     0.317378  -6.284800  0.368642
# 1    0.194005 -0.156368    0.012878     0.344648  -3.792976  0.179656
# 2    0.194587 -0.155760    0.012285     0.342289  -3.959437  0.177013
# 3    0.193152 -0.155204    0.014140     0.335229  -3.838475  0.181155
# 4    0.212436 -0.170060    0.003971     0.312010  -0.426539  0.358667
#
#      gaze_y     label
# 0  0.263187  confused
# 1  0.241120  confused
# 2  0.240378  confused
# 3  0.237476  confused
# 4  0.370636  confused

# %%
df.to_csv("features.csv", index=False)

# %%
# %pip install seaborn
# %pip install matplotlib
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached matplotlib-3.10.8-cp311-cp311-win_amd64.whl.metadata (52 kB)
# ...
#   Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.61.1-cp311-cp311-win_amd64.whl.metadata (116 kB)
# ...
#   Using cached kiwisolver-1.4.9-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# ...
#   Using cached pyparsing-3.3.1-py3-none-any.whl.metadata (5.6 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached matplotlib-3.10.8-cp311-cp311-win_amd64.whl (8.1 MB)
# Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.61.1-cp311-cp311-win_amd64.whl (2.3 MB)
# Using cached kiwisolver-1.4.9-cp311-cp311-win_amd64.whl (73 kB)
# Using cached pyparsing-3.3.1-py3-none-any.whl (121 kB)
# ...
#
# ...

# %%
df.groupby("label").mean()
# Out:
#               brow_ratio  smile_up  mouth_open  mouth_width  head_roll  \
# label
# confused        0.206598 -0.233021    0.018103     0.351620  -3.225480
# happy           0.205951 -0.140933    0.086219     0.483180  -0.782053
# not_confused    0.216713 -0.229811    0.071127     0.372625  -0.711017
# nothappy        0.203987 -0.196120    0.016606     0.361592  -1.367157
#
#                 gaze_x    gaze_y
# label
# confused      0.246741  0.248641
# happy         0.234173  0.256542
# not_confused  0.250197  0.280472
# nothappy      0.247442  0.222348

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df, x="brow_ratio", hue="label", kde=True)
plt.show()
